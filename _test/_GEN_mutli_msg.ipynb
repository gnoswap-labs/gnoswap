# %%
from string import Template 

from datetime import timezone 
import datetime

# %%
ADDR_TEST1 = "g1jg8mtutu9khhfwc4nxmuhcpftf0pajdhfvsqf5" # as lp

ADDR_POOL = "g15z32w7txv6lw259xzhzzmwtwmcjjc0m6dqzh6f"
ADDR_POS = "g10wwa53xgu4397kvzz7akxar9370zjdpwux5th9"
ADDR_STAKER = "g1puv9dz470prjshjm9qyg25dyfvrgph2kvjph68"
ADDR_ROUTER = "g1pjtpgjpsn4hjfv2n4mpz8cczdn32jkpsqwxuav"
ADDR_GOV = "g1kmat25auuqf0h5qvd4q7s707r8let5sky4tr76"

TX_EXPIRE = 9999999999

# %%
t = Template('{"@type":"/vm.m_call","caller":"$caller","send":"$send","pkg_path":"$pkg_path","func":"$func","args":$args}')
tna = Template('{"@type":"/vm.m_call","caller":"$caller","send":"$send","pkg_path":"$pkg_path","func":"$func"}')

# %%
test1_msgs = ""
tr01_msgs = ""

# %%
def faucet_approve(msgs, caller, pkg_path, spender, amount):
    msg = tna.substitute(caller=caller, send='', pkg_path=pkg_path, func='FaucetL')
    msgs += msg
    msgs += ","
    
    msg = t.substitute(caller=caller, send='', pkg_path=pkg_path, func='Approve', args=f'["{spender}","{amount}"]')
    msgs += msg
    msgs += ","
    
    return msgs

def approve(msgs, caller, pkg_path, spender, amount):
    msg = t.substitute(caller=caller, send='', pkg_path=pkg_path, func='Approve', args=f'["{spender}","{amount}"]')
    msgs += msg
    msgs += ","
    
    return msgs

# %%
test1_msgs = ""
tr01_msgs = ""


test1_msgs = approve(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token01", ADDR_POOL, 10_000_000_000_000_000)
test1_msgs = approve(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token02", ADDR_POOL, 10_000_000_000_000_000)
test1_msgs = approve(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token03", ADDR_POOL, 10_000_000_000_000_000)
test1_msgs = approve(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token04", ADDR_POOL, 10_000_000_000_000_000)
test1_msgs = approve(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token05", ADDR_POOL, 10_000_000_000_000_000)
test1_msgs = approve(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token06", ADDR_POOL, 10_000_000_000_000_000)
test1_msgs = approve(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token07", ADDR_POOL, 10_000_000_000_000_000)
test1_msgs = approve(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token08", ADDR_POOL, 10_000_000_000_000_000)
test1_msgs = approve(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token09", ADDR_POOL, 10_000_000_000_000_000)
test1_msgs = approve(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token10", ADDR_POOL, 10_000_000_000_000_000)
test1_msgs = approve(test1_msgs, ADDR_TEST1, "gno.land/r/demo/wugnot", ADDR_POOL, 10_000_000_000_000_000)
test1_msgs = approve(test1_msgs, ADDR_TEST1, "gno.land/r/demo/gns", ADDR_POOL, 500 * 100)

# %%
def pool_init(msgs, caller):
    msg = tna.substitute(caller=caller, send='', pkg_path='gno.land/r/demo/pool', func='InitManual')
    msgs += msg
    msgs += ","
    
    return msgs
    
test1_msgs = pool_init(test1_msgs, ADDR_TEST1)

# %%
min_tick = -887272
max_tick = 887272

q96 = 2**96
eth = 10**18


def tick_to_sqrtp(t):
    return int((1.0001 ** (t / 2)) * q96)

tick_to_sqrtp(630)
# Out:
# 81763443931694820678246072320

# %%
def pool_create(msgs, caller, tokenA, tokenB, fee, sqrtX96):
    msg = t.substitute(caller=caller, send='', pkg_path='gno.land/r/demo/pool', func='CreatePool', args=f'["{tokenA}","{tokenB}","{fee}","{sqrtX96}"]')
    msgs += msg
    msgs += ","
    
    return msgs

test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token01", "gno.land/r/demo/token02", 100, tick_to_sqrtp(630))
test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token01", "gno.land/r/demo/token02", 500, tick_to_sqrtp(620))
test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token01", "gno.land/r/demo/token02", 10000, tick_to_sqrtp(800))

test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token01", "gno.land/r/demo/token03", 100, tick_to_sqrtp(8134))
test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token01", "gno.land/r/demo/token03", 500, tick_to_sqrtp(8090))
test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token01", "gno.land/r/demo/token03", 3000, tick_to_sqrtp(8160))

test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token01", "gno.land/r/demo/token04", 100, tick_to_sqrtp(15810))
test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token01", "gno.land/r/demo/token04", 500, tick_to_sqrtp(15860))
test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token01", "gno.land/r/demo/token04", 10000, tick_to_sqrtp(15800))

test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token01", "gno.land/r/demo/token05", 100, tick_to_sqrtp(27364))
test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token01", "gno.land/r/demo/token05", 500, tick_to_sqrtp(27310))
test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token01", "gno.land/r/demo/token05", 3000, tick_to_sqrtp(27300))

test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token01", "gno.land/r/demo/token06", 100, tick_to_sqrtp(24362))
test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token01", "gno.land/r/demo/token06", 500, tick_to_sqrtp(24360))
test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token01", "gno.land/r/demo/token06", 10000, tick_to_sqrtp(24200))

test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token01", "gno.land/r/demo/token07", 100, tick_to_sqrtp(16106))
test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token01", "gno.land/r/demo/token07", 500, tick_to_sqrtp(16090))
test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token01", "gno.land/r/demo/token07", 3000, tick_to_sqrtp(16020))

test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token02", "gno.land/r/demo/token03", 100, tick_to_sqrtp(7466))
test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token02", "gno.land/r/demo/token03", 500, tick_to_sqrtp(7480))
test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token02", "gno.land/r/demo/token03", 10000, tick_to_sqrtp(7400))

test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token02", "gno.land/r/demo/token04", 100, tick_to_sqrtp(15108))
test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token02", "gno.land/r/demo/token04", 500, tick_to_sqrtp(15260))
test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token02", "gno.land/r/demo/token04", 3000, tick_to_sqrtp(15240))

test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token02", "gno.land/r/demo/token05", 100, tick_to_sqrtp(26746))
test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token02", "gno.land/r/demo/token05", 500, tick_to_sqrtp(26400))
test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token02", "gno.land/r/demo/token05", 10000, tick_to_sqrtp(26600))

test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token02", "gno.land/r/demo/token06", 100, tick_to_sqrtp(23810))
test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token02", "gno.land/r/demo/token06", 500, tick_to_sqrtp(23710))
test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token02", "gno.land/r/demo/token06", 3000, tick_to_sqrtp(23760))

test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token02", "gno.land/r/demo/token07", 100, tick_to_sqrtp(15580))
test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token02", "gno.land/r/demo/token07", 500, tick_to_sqrtp(15670))
test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token02", "gno.land/r/demo/token07", 10000, tick_to_sqrtp(15600))

test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token03", "gno.land/r/demo/token04", 100, tick_to_sqrtp(7584))
test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token03", "gno.land/r/demo/token04", 500, tick_to_sqrtp(7650))
test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token03", "gno.land/r/demo/token04", 3000, tick_to_sqrtp(7740))

test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token03", "gno.land/r/demo/token05", 100, tick_to_sqrtp(19310))
test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token03", "gno.land/r/demo/token05", 500, tick_to_sqrtp(19400))
test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token03", "gno.land/r/demo/token05", 10000, tick_to_sqrtp(19400))

test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token03", "gno.land/r/demo/token06", 100, tick_to_sqrtp(16302))
test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token03", "gno.land/r/demo/token06", 500, tick_to_sqrtp(16330))
test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token03", "gno.land/r/demo/token06", 3000, tick_to_sqrtp(16560))

test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token03", "gno.land/r/demo/token07", 100, tick_to_sqrtp(8164))
test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token03", "gno.land/r/demo/token07", 500, tick_to_sqrtp(8060))
test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token03", "gno.land/r/demo/token07", 10000, tick_to_sqrtp(8400))

test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token04", "gno.land/r/demo/token05", 100, tick_to_sqrtp(11468))
test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token04", "gno.land/r/demo/token05", 500, tick_to_sqrtp(11750))
test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token04", "gno.land/r/demo/token05", 3000, tick_to_sqrtp(11700))

test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token04", "gno.land/r/demo/token06", 100, tick_to_sqrtp(8508))
test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token04", "gno.land/r/demo/token06", 500, tick_to_sqrtp(8990))
test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token04", "gno.land/r/demo/token06", 10000, tick_to_sqrtp(9000))

test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token04", "gno.land/r/demo/token07", 100, tick_to_sqrtp(258))
test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token04", "gno.land/r/demo/token07", 500, tick_to_sqrtp(850))
test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token04", "gno.land/r/demo/token07", 3000, tick_to_sqrtp(840))

test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token05", "gno.land/r/demo/token06", 100, tick_to_sqrtp(-2692))
test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token05", "gno.land/r/demo/token06", 500, tick_to_sqrtp(-2970))
test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token05", "gno.land/r/demo/token06", 10000, tick_to_sqrtp(-2600))

test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token05", "gno.land/r/demo/token07", 100, tick_to_sqrtp(-11292))
test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token05", "gno.land/r/demo/token07", 500, tick_to_sqrtp(-10800))
test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token05", "gno.land/r/demo/token07", 3000, tick_to_sqrtp(-11100))

test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token06", "gno.land/r/demo/token07", 100, tick_to_sqrtp(-8000))
test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token06", "gno.land/r/demo/token07", 500, tick_to_sqrtp(-8190))
test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token06", "gno.land/r/demo/token07", 10000, tick_to_sqrtp(-7800))

# %%
def position_mint(msgs, caller, send, tokenA, tokenB, fee, minTick, maxTick, maxA, maxB, minA, minB):  
    msg = t.substitute(caller=caller, send=send, pkg_path='gno.land/r/demo/position', func='Mint', args=f'["{tokenA}","{tokenB}","{fee}","{minTick}","{maxTick}","{maxA}","{maxB}","{minA}","{minB}","{TX_EXPIRE}"]')
    msgs += msg
    msgs += ","

    return msgs

    
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token01", "gno.land/r/demo/token02", 100, -1054,952,399000,399000,0,0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token01", "gno.land/r/demo/token02", 100, -2168,50,400000,400000,0,0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token01", "gno.land/r/demo/token02", 500, -6440,7420,1070000,1070000,0,0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token01", "gno.land/r/demo/token02", 500, 440,2270,1850000,1850000,0,0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token01", "gno.land/r/demo/token02", 10000, 400,17000,10230000,10230000,0,0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token01", "gno.land/r/demo/token02", 10000, -15200,1400,15040000,15040000,0,0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token01", "gno.land/r/demo/token03", 100, 6804,8810,616000,616000,0,0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token01", "gno.land/r/demo/token03", 100, 5688,7906,17000000,17000000,0,0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token01", "gno.land/r/demo/token03", 500, 1410,15280,2200000,2200000,0,0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token01", "gno.land/r/demo/token03", 500, 8290,10130,2000000,200000,0,0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token01", "gno.land/r/demo/token03", 3000, 8280,24900,105000,105000,0,0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token01", "gno.land/r/demo/token03", 3000, -7260,9300,14069000,14069000,0,0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token01", "gno.land/r/demo/token04", 100, 14324,16330,1460000,1460000,0,0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token01", "gno.land/r/demo/token04", 100, 13208,15426,51250000,51250000,0,0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token01", "gno.land/r/demo/token04", 500, 8930,22800,4877000,4877000,0,0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token01", "gno.land/r/demo/token04", 500, 15810,17650,1000000,1000000,0,0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token01", "gno.land/r/demo/token04", 10000, 15800,32400,1060000,1060000,0,0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token01", "gno.land/r/demo/token04", 10000, 200,16800,34140000,34140000,0,0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token01", "gno.land/r/demo/token05", 100, 25698,27704,5140000,5140000,0,0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token01", "gno.land/r/demo/token05", 100, 24582,26802,15810000,15810000,0,0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token01", "gno.land/r/demo/token05", 500, 20310,34170,7710000,7710000,0,0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token01", "gno.land/r/demo/token05", 500, 27190,29020,23680000,2680000,0,0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token01", "gno.land/r/demo/token05", 3000, 27180,43800,1040000,1040000,0,0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token01", "gno.land/r/demo/token05", 3000, 11580,28200,35940000,35940000,0,0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token01", "gno.land/r/demo/token06", 100, 22718,24726,3760000,3760000,0,0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token01", "gno.land/r/demo/token06", 100, 21604,23822,400000,400000,0,0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token01", "gno.land/r/demo/token06", 500, 17330,31190,11510000,11510000,0,0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token01", "gno.land/r/demo/token06", 500, 24210,26040,2020000,2020000,0,0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token01", "gno.land/r/demo/token06", 10000, 24200,40800,1050000,1050000,0,0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token01", "gno.land/r/demo/token06", 10000, 8600,25200,31850000,31850000,0,0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token01", "gno.land/r/demo/token07", 100, 14432,16438,1670000,1670000,0,0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token01", "gno.land/r/demo/token07", 100, 13316,15534,400,400,0,0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token01", "gno.land/r/demo/token07", 500, 9040,22900,5040000,5040000,0,0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token01", "gno.land/r/demo/token07", 500, 15920,17750,1860000,186000,0,0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token01", "gno.land/r/demo/token07", 3000, 15900,32520,1040000,1040000,0,0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token01", "gno.land/r/demo/token07", 3000, 360,16920,29040000,29040000,0,0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token02", "gno.land/r/demo/token03", 100, 5878,7884,676000,676000,0,0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token02", "gno.land/r/demo/token03", 100, 4762,6982,400000,400000,0,0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token02", "gno.land/r/demo/token03", 500, 490,14350,2120000,2120000,0,0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token02", "gno.land/r/demo/token03", 500, 7370,9200,1930000,1930000,0,0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token02", "gno.land/r/demo/token03", 10000, 7400,24000,1030000,1030000,0,0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token02", "gno.land/r/demo/token03", 10000, -8200,8400,9820000,9820000,0,0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token02", "gno.land/r/demo/token04", 100, 13736,15742,1270000,1270000,0,0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token02", "gno.land/r/demo/token04", 100, 12620,14838,400000,400000,0,0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token02", "gno.land/r/demo/token04", 500, 8340,22210,4598000,4598000,0,0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token02", "gno.land/r/demo/token04", 500, 15230,17060,2020000,2020000,0,0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token02", "gno.land/r/demo/token04", 3000, 15240,31860,1040000,1040000,0,0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token02", "gno.land/r/demo/token04", 3000, -360,16200,26810000,26810000,0,0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token02", "gno.land/r/demo/token05", 100, 25310,27316,4240000,4240000,0,0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token02", "gno.land/r/demo/token05", 100, 24194,26414,400000,400000,0,0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token02", "gno.land/r/demo/token05", 500, 19920,33780,13540000,13540000,0,0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token02", "gno.land/r/demo/token05", 500, 26800,28630,2060000,2060000,0,0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token02", "gno.land/r/demo/token05", 10000, 26800,43400,1060000,0,0,0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token02", "gno.land/r/demo/token05", 10000, 11200,27800,40030000,40030000,0,0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token02", "gno.land/r/demo/token06", 100, 22130,24138,3630000,3630000,0,0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token02", "gno.land/r/demo/token06", 100, 21016,23234,400000,400000,0,0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token02", "gno.land/r/demo/token06", 500, 16840,30600,10730000,10730000,0,0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token02", "gno.land/r/demo/token06", 500, 23620,25450,1950000,1950000,0,0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token02", "gno.land/r/demo/token06", 3000, 23640,40260,1030000,1030000,0,0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token02", "gno.land/r/demo/token06", 3000, 8040,24600,62930000,62930000,0,0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token02", "gno.land/r/demo/token07", 100, 13944,15950,1560000,1560000,0,0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token02", "gno.land/r/demo/token07", 100, 12828,15046,400000,400000,0,0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token02", "gno.land/r/demo/token07", 500, 8550,22420,4850000,4850000,0,0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token02", "gno.land/r/demo/token07", 500, 15430,17270,1770000,1770000,0,0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token02", "gno.land/r/demo/token07", 10000, -15400,32000,1770000,1770000,0,0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token02", "gno.land/r/demo/token07", 10000, -200,16400,33720000,33720000,0,0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token03", "gno.land/r/demo/token04", 100, 5878,7884,727000,727000,0,0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token03", "gno.land/r/demo/token04", 100, 4762,6982,400000,400000,0,0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token03", "gno.land/r/demo/token04", 500, 490,14350,2180000,20180000,0,0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token03", "gno.land/r/demo/token04", 500, 7370,9200,1730000,1730000,0,0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token03", "gno.land/r/demo/token04", 3000, 7380,24000,1010000,1010000,0,0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token03", "gno.land/r/demo/token04", 3000, -8220,8400,45100000,45100000,0,0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token03", "gno.land/r/demo/token05", 100, 17790,19796,2120000,2120000,0,0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token03", "gno.land/r/demo/token05", 100, 16674,18894,400000,400000,0,0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token03", "gno.land/r/demo/token05", 500, 12400,26260,7000000,7000000,0,0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token03", "gno.land/r/demo/token05", 500, 19280,21110,1910000,1910000,0,0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token03", "gno.land/r/demo/token05", 10000, 19200,35800,1030000,1030000,0,0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token03", "gno.land/r/demo/token05", 10000, 3800,20200,49070000,49070000,0,0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token03", "gno.land/r/demo/token06", 100, 14812,16818,1540000,1540000,0,0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token03", "gno.land/r/demo/token06", 100, 13696,15914,400000,400000,0,0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token03", "gno.land/r/demo/token06", 500, 9420,23280,5110000,5110000,0,0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token03", "gno.land/r/demo/token06", 500, 16300,18130,2030000,2030000,0,0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token03", "gno.land/r/demo/token06", 3000, 16320,32940,1020000,1020000,0,0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token03", "gno.land/r/demo/token06", 3000, 720,17280,30480000,30480000,0,0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token03", "gno.land/r/demo/token07", 100, 6524,8530,744000,744000,0,0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token03", "gno.land/r/demo/token07", 100, 5408,7628,400000,400000,0,0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token03", "gno.land/r/demo/token07", 500, 1130,15000,2240000,2240000,0,0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token03", "gno.land/r/demo/token07", 500, 8010,9850,2010000,2010000,0,0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token03", "gno.land/r/demo/token07", 10000, 8000,24600,1020000,1020000,0,0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token03", "gno.land/r/demo/token07", 10000, -7600,9000,16350000,16350000,0,0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token04", "gno.land/r/demo/token05", 100, 9932,11940,97883,975000,0,0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token04", "gno.land/r/demo/token05", 100, 8816,11036,400000,400000,0,0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token04", "gno.land/r/demo/token05", 500, 4540,18410,3300000,3300000,0,0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token04", "gno.land/r/demo/token05", 500, 11420,13260,1680000,1680000,0,0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token04", "gno.land/r/demo/token05", 3000, 11400,28020,1020000,1020000,0,0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token04", "gno.land/r/demo/token05", 3000, -4140,12420,18870000,18870000,0,0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token04", "gno.land/r/demo/token06", 100, 7292,9298,589000,589000,0,0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token04", "gno.land/r/demo/token06", 100, 6176,8394,400000,400000,0,0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token04", "gno.land/r/demo/token06", 500, 1900,15760,2480000,2480000,0,0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token04", "gno.land/r/demo/token06", 500, 8780,10610,1820000,1820000,0,0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token04", "gno.land/r/demo/token06", 10000, 8800,25400,10150000,10150000,0,0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token04", "gno.land/r/demo/token06", 10000, -6800,9800,57560000,57560000,0,0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token04", "gno.land/r/demo/token07", 100, -796,1210,226000,226000,0,0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token04", "gno.land/r/demo/token07", 100, -1910,308,14010000,14010000,0,0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token04", "gno.land/r/demo/token07", 500, -6190,7680,1100000,1100000,0,0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token04", "gno.land/r/demo/token07", 500, 700,2530,9410000,9410000,0,0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token04", "gno.land/r/demo/token07", 3000, 720,17280,6190000,6190000,0,0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token04", "gno.land/r/demo/token07", 3000, -14880,1680,38170000,38170000,0,0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token05", "gno.land/r/demo/token06", 100, -4620,-2614,289000,289000,0,0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token05", "gno.land/r/demo/token06", 100, -5736,-3516,400000,400000,0,0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token05", "gno.land/r/demo/token06", 500, -10010,3850,981000,981000,0,0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token05", "gno.land/r/demo/token06", 500, -3130,-1300,9370000,9370000,0,0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token05", "gno.land/r/demo/token06", 10000, -3200,13400,10000000,10000000,0,0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token05", "gno.land/r/demo/token06", 10000, -18800,-2200,43235000,43235000,0,0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token05", "gno.land/r/demo/token07", 100, -12370,-10362,195000,195000,0,0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token05", "gno.land/r/demo/token07", 100, -13486,-11266,394000,394000,0,0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token05", "gno.land/r/demo/token07", 500, -17760,-3900,994000,994000,0,0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token05", "gno.land/r/demo/token07", 500, -10880,-9050,19640000,19640000,0,0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token05", "gno.land/r/demo/token07", 3000, -10860,5760,10440000,10440000,0,0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token05", "gno.land/r/demo/token07", 3000, -26460,-9900,4170000,4170000,0,0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token06", "gno.land/r/demo/token07", 100, -9728,-7722,154000,154000,0,0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token06", "gno.land/r/demo/token07", 100, -10844,-8626,400000,400000,0,0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token06", "gno.land/r/demo/token07", 500, -15120,-1260,1000000,1000000,0,0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token06", "gno.land/r/demo/token07", 500, -8240,-6410,10000000,10000000,0,0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token06", "gno.land/r/demo/token07", 10000, -8200,8400,10000000,10000000,0,0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token06", "gno.land/r/demo/token07", 10000, -23800,-7200,8556000,8556000,0,0)

# %%
## FINAL
multi_msg_01 = test1_msgs[:-1]
multi_msg_01 = f'"msg":[{multi_msg_01}]'
multi_msg_01 = '{' + multi_msg_01 + ',"fee":{"gas_wanted":"9000000","gas_fee":"1ugnot"},"signatures":null,"memo":""}'


with open("multi_msg_test1.txt", "w") as f:
    f.write(multi_msg_01)

# %%
# def staker_create(msgs, caller, send, targetPath, rewardToken, rewardAmount, startTime, endTime):
#     msg = t.substitute(caller=caller, send=send, pkg_path='gno.land/r/staker', func='CreateExternalIncentive', args=f'["{targetPath}","{rewardToken}","{rewardAmount}","{startTime}","{endTime}"]')
#     msgs += msg
#     msgs += ","
    
#     return msgs

    
# dt = datetime.datetime.now(timezone.utc) 
# utc_time = dt.replace(tzinfo=timezone.utc) 
# utc_timestamp = utc_time.timestamp() 

# incentive_start = utc_timestamp
# incentive_end = incentive_start + 100

# gsa_msgs = staker_create(gsa_msgs, ADDR_GSA, "", "gno.land/r/bar:gnot:10", "gno.land/r/obl", "10000000000", incentive_start, incentive_end)

# %%
# def staker_stake(msgs, caller, tokenId):
#     msg = t.substitute(caller=caller, send='', pkg_path='gno.land/r/gnft', func='Approve', args=f'["{ADDR_STAKER}","{tokenId}"]')
#     msgs += msg
#     msgs += ","
    
#     msg = t.substitute(caller=caller, send='', pkg_path='gno.land/r/staker', func='StakeToken', args=f'["{tokenId}"]')
#     msgs += msg
#     msgs += ","
    
#     return msgs
    
    
# lp01_msgs = staker_stake(lp01_msgs, ADDR_LP01, 1)
# lp02_msgs = staker_stake(lp02_msgs, ADDR_LP02, 2)#

# %%
# def pool_set_protocol_fee(msgs, caller, feeA, feeB):    
#     msg = t.substitute(caller=caller, send='', pkg_path='gno.land/r/pool', func='SetFeeProtocol', args=f'["{feeA}","{feeB}"]')
#     msgs += msg
#     msgs += ","
    
#     return msgs
    
    
# gsa_msgs = pool_set_protocol_fee(gsa_msgs, ADDR_GSA, 6, 8)

# %%
# def router_swap(msgs, caller, send, tokenIn, tokenOut, amountSpecified, swapType, strRoutes, strQuotes, swapResultLimit):
#     msg = t.substitute(caller=caller, send=send, pkg_path='gno.land/r/router', func='SwapRoute', args=f'["{tokenIn}","{tokenOut}","{amountSpecified}","{swapType}","{strRoutes}","{strQuotes}","{swapResultLimit}"]')
#     msgs += msg
#     msgs += ","
    
#     return msgs

    
# tr01_msgs = router_swap(tr01_msgs, ADDR_TR01, "", "gno.land/r/bar", "gno.land/r/baz", 123456, "EXACT_IN", "gno.land/r/bar:gno.land/r/baz:100", "100", 200000)
# tr01_msgs = router_swap(tr01_msgs, ADDR_TR01, "100000000ugnot", "gnot", "gno.land/r/qux", 987654, "EXACT_OUT", "gnot:gno.land/r/bar:100*POOL*gno.land/r/bar:gno.land/r/baz:100*POOL*gno.land/r/baz:gno.land/r/qux:100,gnot:gno.land/r/bar:500*POOL*gno.land/r/bar:gno.land/r/baz:500*POOL*gno.land/r/baz:gno.land/r/qux:500", "40,60", 654321)

# %%
# def position_collect(msgs, caller, tokenId, recipient, amount0, amount1):
#     msg = t.substitute(caller=caller, send='', pkg_path='gno.land/r/position', func='Collect', args=f'["{tokenId}","{recipient}","{amount0}","{amount1}"]')
#     msgs += msg
#     msgs += ","
    
#     return msgs
    

# lp01_msgs = position_collect(lp01_msgs, ADDR_LP01, 1, ADDR_LP01, 1000000, 1000000)
# lp01_msgs = position_collect(lp01_msgs, ADDR_LP02, 2, ADDR_LP01, 1000000, 1000000)

# %%
# def staker_unstake(msgs, caller, tokenId):
#     msg = t.substitute(caller=caller, send='', pkg_path='gno.land/r/staker', func='UnstakeToken', args=f'["{tokenId}"]')
#     msgs += msg
#     msgs += ","
    
#     return msgs
