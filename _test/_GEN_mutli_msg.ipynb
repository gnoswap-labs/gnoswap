# %%
from string import Template 

from datetime import timezone 
import datetime

# %%
ADDR_TEST1 = "g1jg8mtutu9khhfwc4nxmuhcpftf0pajdhfvsqf5" # as lp

ADDR_POOL = "g15z32w7txv6lw259xzhzzmwtwmcjjc0m6dqzh6f"
ADDR_POS = "g10wwa53xgu4397kvzz7akxar9370zjdpwux5th9"
ADDR_STAKER = "g1puv9dz470prjshjm9qyg25dyfvrgph2kvjph68"
ADDR_ROUTER = "g1pjtpgjpsn4hjfv2n4mpz8cczdn32jkpsqwxuav"
ADDR_GOV = "g1kmat25auuqf0h5qvd4q7s707r8let5sky4tr76"

TX_EXPIRE = 9999999999

# %%
t = Template('{"@type":"/vm.m_call","caller":"$caller","send":"$send","pkg_path":"$pkg_path","func":"$func","args":$args}')
tna = Template('{"@type":"/vm.m_call","caller":"$caller","send":"$send","pkg_path":"$pkg_path","func":"$func"}')

# %%
test1_msgs = ""
tr01_msgs = ""

# %%
def faucet_approve(msgs, caller, pkg_path, spender, amount):
    msg = tna.substitute(caller=caller, send='', pkg_path=pkg_path, func='FaucetL')
    msgs += msg
    msgs += ","
    
    msg = t.substitute(caller=caller, send='', pkg_path=pkg_path, func='Approve', args=f'["{spender}","{amount}"]')
    msgs += msg
    msgs += ","
    
    return msgs

def approve(msgs, caller, pkg_path, spender, amount):
    msg = t.substitute(caller=caller, send='', pkg_path=pkg_path, func='Approve', args=f'["{spender}","{amount}"]')
    msgs += msg
    msgs += ","
    
    return msgs

# %%
test1_msgs = ""
tr01_msgs = ""


test1_msgs = approve(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token01", ADDR_POOL, 10_000_000_000_000_000)
test1_msgs = approve(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token02", ADDR_POOL, 10_000_000_000_000_000)
test1_msgs = approve(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token03", ADDR_POOL, 10_000_000_000_000_000)
test1_msgs = approve(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token04", ADDR_POOL, 10_000_000_000_000_000)
test1_msgs = approve(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token05", ADDR_POOL, 10_000_000_000_000_000)
test1_msgs = approve(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token06", ADDR_POOL, 10_000_000_000_000_000)
test1_msgs = approve(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token07", ADDR_POOL, 10_000_000_000_000_000)
test1_msgs = approve(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token08", ADDR_POOL, 10_000_000_000_000_000)
test1_msgs = approve(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token09", ADDR_POOL, 10_000_000_000_000_000)
test1_msgs = approve(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token10", ADDR_POOL, 10_000_000_000_000_000)
test1_msgs = approve(test1_msgs, ADDR_TEST1, "gno.land/r/demo/wugnot", ADDR_POOL, 10_000_000_000_000_000)
test1_msgs = approve(test1_msgs, ADDR_TEST1, "gno.land/r/demo/gns", ADDR_POOL, 500 * 100)

# %%
def pool_init(msgs, caller):
    msg = tna.substitute(caller=caller, send='', pkg_path='gno.land/r/demo/pool', func='InitManual')
    msgs += msg
    msgs += ","
    
    return msgs
    
test1_msgs = pool_init(test1_msgs, ADDR_TEST1)

# %%
def pool_create(msgs, caller, tokenA, tokenB, fee, sqrtX96):
    msg = t.substitute(caller=caller, send='', pkg_path='gno.land/r/demo/pool', func='CreatePool', args=f'["{tokenA}","{tokenB}","{fee}","{sqrtX96}"]')
    msgs += msg
    msgs += ","
    
    return msgs

test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token01", "gno.land/r/demo/token02", 100, 79228162514264337593543950337) # x1
test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token02", "gno.land/r/demo/token03", 100, 177166786517138269218369076073) # x5
test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token01", "gno.land/r/demo/token02", 10000, 79228162514264337593543950337) # x1
test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token02", "gno.land/r/demo/token03", 10000, 194073514576992249379660408880) # x6

test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token04", "gno.land/r/demo/token05", 100, 25054147597456445214093764435) # x0.1
test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token05", "gno.land/r/demo/token06", 100, 17716682555034377259603427773) # x0.5
test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token04", "gno.land/r/demo/token05", 10000, 25054147597456445214093764435) # x0.1
test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token05", "gno.land/r/demo/token06", 10000, 19407355733507081572369655227) # x0.6

test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token03", "gno.land/r/demo/token08", 3000, 5602503859762671191748202504234) # x5000
test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token06", "gno.land/r/demo/token10", 3000, 5602507562777276312411137859) # x0.005

test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token07", "gno.land/r/demo/token08", 100, 112046559425783515914356180039) # x2
test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token07", "gno.land/r/demo/token08", 10000, 250541420775534450580036817218) # x10
test1_msgs = pool_create(test1_msgs, ADDR_TEST1, "gno.land/r/demo/token08", "gno.land/r/demo/token09", 100, 177166786517138269218369076073) # x5

# %%
def position_mint(msgs, caller, send, tokenA, tokenB, fee, minTick, maxTick, maxA, maxB, minA, minB):  
    msg = t.substitute(caller=caller, send=send, pkg_path='gno.land/r/demo/position', func='Mint', args=f'["{tokenA}","{tokenB}","{fee}","{minTick}","{maxTick}","{maxA}","{maxB}","{minA}","{minB}","{TX_EXPIRE}"]')
    msgs += msg
    msgs += ","

    return msgs

    
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token01", "gno.land/r/demo/token02", 100, -500, 500, 1_000_000_000_000, 1_000_000_000_000, 0, 0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token01", "gno.land/r/demo/token02", 100, -1000, -500, 1_000_000_000_000, 1_000_000_000_000, 0, 0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token02", "gno.land/r/demo/token03", 100, 15096, 17096, 1_000_000_000_000, 1_000_000_000_000, 0, 0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token02", "gno.land/r/demo/token03", 100, 15000, 16000, 1_000_000_000_000, 1_000_000_000_000, 0, 0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token01", "gno.land/r/demo/token02", 10000, -600, 600, 1_000_000_000_000, 1_000_000_000_000, 0, 0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token01", "gno.land/r/demo/token02", 10000, 600, 1200, 1_000_000_000_000, 1_000_000_000_000, 0, 0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token02", "gno.land/r/demo/token03", 10000, 16800, 18800, 1_000_000_000_000, 1_000_000_000_000, 0, 0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token02", "gno.land/r/demo/token03", 10000, 19000, 20000, 1_000_000_000_000, 1_000_000_000_000, 0, 0)



test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token04", "gno.land/r/demo/token05", 100, -24028, -22028, 1_000_000_000_000, 1_000_000_000_000, 0, 0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token04", "gno.land/r/demo/token05", 100, -26028, -24028, 1_000_000_000_000, 1_000_000_000_000, 0, 0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token05", "gno.land/r/demo/token06", 100, -30958, -28858, 1_000_000_000_000, 1_000_000_000_000, 0, 0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token05", "gno.land/r/demo/token06", 100, -31958, -30958, 1_000_000_000_000, 1_000_000_000_000, 0, 0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token04", "gno.land/r/demo/token05", 10000, -24000, -22000, 1_000_000_000_000, 1_000_000_000_000, 0, 0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token04", "gno.land/r/demo/token05", 10000, -21000, -20000, 1_000_000_000_000, 1_000_000_000_000, 0, 0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token05", "gno.land/r/demo/token06", 10000, -29000, -27000, 1_000_000_000_000, 1_000_000_000_000, 0, 0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token05", "gno.land/r/demo/token06", 10000, -26000, -25000, 1_000_000_000_000, 1_000_000_000_000, 0, 0)


test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token03", "gno.land/r/demo/token08", 3000, 84180, 86160, 1_000_000_000_000, 1_000_000_000_000, 0, 0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token03", "gno.land/r/demo/token08", 3000, 82140, 83160, 1_000_000_000_000, 1_000_000_000_000, 0, 0)

test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token06", "gno.land/r/demo/token10", 3000, -53940, -51960, 1_000_000_000_000, 1_000_000_000_000, 0, 0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token06", "gno.land/r/demo/token10", 3000, -50940, -49980, 1_000_000_000_000, 1_000_000_000_000, 0, 0)


test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token07", "gno.land/r/demo/token08", 100, 5932, 7932, 1_000_000_000, 1_000_000_000, 0, 0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token07", "gno.land/r/demo/token08", 10000, 21000, 22000, 1_000_000_000, 1_000_000_000, 0, 0)
test1_msgs = position_mint(test1_msgs, ADDR_TEST1, "", "gno.land/r/demo/token08", "gno.land/r/demo/token09", 100, 14096, 15096, 1_000_000_000, 1_000_000_000, 0, 0)

# %%
## FINAL
multi_msg_01 = test1_msgs[:-1]
multi_msg_01 = f'"msg":[{multi_msg_01}]'
multi_msg_01 = '{' + multi_msg_01 + ',"fee":{"gas_wanted":"9000000","gas_fee":"1ugnot"},"signatures":null,"memo":""}'


with open("multi_msg_test1.txt", "w") as f:
    f.write(multi_msg_01)

# %%
# def staker_create(msgs, caller, send, targetPath, rewardToken, rewardAmount, startTime, endTime):
#     msg = t.substitute(caller=caller, send=send, pkg_path='gno.land/r/staker', func='CreateExternalIncentive', args=f'["{targetPath}","{rewardToken}","{rewardAmount}","{startTime}","{endTime}"]')
#     msgs += msg
#     msgs += ","
    
#     return msgs

    
# dt = datetime.datetime.now(timezone.utc) 
# utc_time = dt.replace(tzinfo=timezone.utc) 
# utc_timestamp = utc_time.timestamp() 

# incentive_start = utc_timestamp
# incentive_end = incentive_start + 100

# gsa_msgs = staker_create(gsa_msgs, ADDR_GSA, "", "gno.land/r/bar:gnot:10", "gno.land/r/obl", "10000000000", incentive_start, incentive_end)

# %%
# def staker_stake(msgs, caller, tokenId):
#     msg = t.substitute(caller=caller, send='', pkg_path='gno.land/r/gnft', func='Approve', args=f'["{ADDR_STAKER}","{tokenId}"]')
#     msgs += msg
#     msgs += ","
    
#     msg = t.substitute(caller=caller, send='', pkg_path='gno.land/r/staker', func='StakeToken', args=f'["{tokenId}"]')
#     msgs += msg
#     msgs += ","
    
#     return msgs
    
    
# lp01_msgs = staker_stake(lp01_msgs, ADDR_LP01, 1)
# lp02_msgs = staker_stake(lp02_msgs, ADDR_LP02, 2)#

# %%
# def pool_set_protocol_fee(msgs, caller, feeA, feeB):    
#     msg = t.substitute(caller=caller, send='', pkg_path='gno.land/r/pool', func='SetFeeProtocol', args=f'["{feeA}","{feeB}"]')
#     msgs += msg
#     msgs += ","
    
#     return msgs
    
    
# gsa_msgs = pool_set_protocol_fee(gsa_msgs, ADDR_GSA, 6, 8)

# %%
# def router_swap(msgs, caller, send, tokenIn, tokenOut, amountSpecified, swapType, strRoutes, strQuotes, swapResultLimit):
#     msg = t.substitute(caller=caller, send=send, pkg_path='gno.land/r/router', func='SwapRoute', args=f'["{tokenIn}","{tokenOut}","{amountSpecified}","{swapType}","{strRoutes}","{strQuotes}","{swapResultLimit}"]')
#     msgs += msg
#     msgs += ","
    
#     return msgs

    
# tr01_msgs = router_swap(tr01_msgs, ADDR_TR01, "", "gno.land/r/bar", "gno.land/r/baz", 123456, "EXACT_IN", "gno.land/r/bar:gno.land/r/baz:100", "100", 200000)
# tr01_msgs = router_swap(tr01_msgs, ADDR_TR01, "100000000ugnot", "gnot", "gno.land/r/qux", 987654, "EXACT_OUT", "gnot:gno.land/r/bar:100*POOL*gno.land/r/bar:gno.land/r/baz:100*POOL*gno.land/r/baz:gno.land/r/qux:100,gnot:gno.land/r/bar:500*POOL*gno.land/r/bar:gno.land/r/baz:500*POOL*gno.land/r/baz:gno.land/r/qux:500", "40,60", 654321)

# %%
# def position_collect(msgs, caller, tokenId, recipient, amount0, amount1):
#     msg = t.substitute(caller=caller, send='', pkg_path='gno.land/r/position', func='Collect', args=f'["{tokenId}","{recipient}","{amount0}","{amount1}"]')
#     msgs += msg
#     msgs += ","
    
#     return msgs
    

# lp01_msgs = position_collect(lp01_msgs, ADDR_LP01, 1, ADDR_LP01, 1000000, 1000000)
# lp01_msgs = position_collect(lp01_msgs, ADDR_LP02, 2, ADDR_LP01, 1000000, 1000000)

# %%
# def staker_unstake(msgs, caller, tokenId):
#     msg = t.substitute(caller=caller, send='', pkg_path='gno.land/r/staker', func='UnstakeToken', args=f'["{tokenId}"]')
#     msgs += msg
#     msgs += ","
    
#     return msgs
